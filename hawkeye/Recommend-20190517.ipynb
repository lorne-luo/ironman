# %% [markdown]
# Step 1. [Download history price and clean data](/notebooks/forex/hawkeye/1_download.ipynb)
#
# Step 2. [Use monte carlo simulate each stock's movement for 10000 times](/notebooks/forex/hawkeye/2_process.ipynb)
#
# **Step 3. Apply some heuristic rules to give stock recommendation**

# %%
import pandas as pd
import matplotlib.pyplot as plt

path = '/opt/hawkeye/data/20190517/result.csv'
df = pd.read_csv(path,
                 usecols=[
                     'code', 'last_date', 'start price', 'sim_mean',
                     'sim_diff', 'VaR 99%', 'VaR 99% Percent', 'volume_mean',
                     'return_mean', 'return_sigma'
                 ])
df.head()
df['return'] = round(df['sim_diff'] / df['start price'] * 100, 3)
print(f'Total stock number = {len(df)}')

print(df['start price'].quantile(0.7))
print('Sim return 90%% percentile = %s' % df['return'].quantile(0.9))

volume_threshold = df['volume_mean'].quantile(0.2)
print(f'Volume 90% percentile = {volume_threshold}')

df = df[(df['volume_mean'] > volume_threshold) & (df['start price'] > 0.1)]
print(len(df))
df.sort_values(by='return', ascending=False).head(10)
# Out:
# Total stock number = 1571
# 0.88
# Sim return 90% percentile = 1.197
# Volume 90% percentile = 40995.62626262626
# 692
#      code   last_date  start price  sim_mean  sim_diff  VaR 99%  \
# 653   FTC  2019-05-10        0.170      0.18  0.008250   0.0562
# 231   AVH  2019-05-16        0.490      0.51  0.021313   0.0612
# 1121  NSC  2019-05-17        0.615      0.64  0.024906   0.2258
# 44    ANO  2019-05-17        4.700      4.87  0.171037   0.4759
# 1511  WGO  2019-05-17        0.140      0.14  0.004907   0.0280
# 1541  WZR  2019-05-17        0.140      0.14  0.004703   0.0230
# 170   ATU  2019-05-16        0.350      0.36  0.011659   0.0470
# 13    8CO  2019-05-16        0.155      0.16  0.005111   0.0207
# 547   E2M  2019-05-10        0.275      0.28  0.008883   0.0331
# 91    AGH  2019-05-17        0.620      0.64  0.016855   0.0547
#
#       VaR 99% Percent   volume_mean  return_mean  return_sigma  return
# 653           33.0320  6.156947e+05     0.025319      0.190321   4.853
# 231           12.4854  8.355594e+06     0.021652      0.075526   4.350
# 1121          36.7117  5.134245e+04     0.019579      0.208017   4.050
# 44            10.1253  9.394618e+04     0.018749      0.063133   3.639
# 1511          19.9841  2.971455e+05     0.018281      0.110493   3.505
# 1541          16.4602  4.452298e+06     0.016131      0.090425   3.359
# 170           13.4391  6.851132e+05     0.016391      0.075468   3.331
# 13            13.3311  2.427746e+05     0.017100      0.074168   3.297
# 547           12.0385  1.754284e+05     0.016824      0.068264   3.230
# 91             8.8263  4.481264e+05     0.013553      0.051464   2.718

# %%
# high mean return 
df.sort_values(by='return', ascending=False).head(10)
# Out:
#      code   last_date  start price  sim_mean  sim_diff  VaR 99%  \
# 653   FTC  2019-05-10        0.170      0.18  0.008250   0.0562
# 231   AVH  2019-05-16        0.490      0.51  0.021313   0.0612
# 1121  NSC  2019-05-17        0.615      0.64  0.024906   0.2258
# 44    ANO  2019-05-17        4.700      4.87  0.171037   0.4759
# 1511  WGO  2019-05-17        0.140      0.14  0.004907   0.0280
# 1541  WZR  2019-05-17        0.140      0.14  0.004703   0.0230
# 170   ATU  2019-05-16        0.350      0.36  0.011659   0.0470
# 13    8CO  2019-05-16        0.155      0.16  0.005111   0.0207
# 547   E2M  2019-05-10        0.275      0.28  0.008883   0.0331
# 91    AGH  2019-05-17        0.620      0.64  0.016855   0.0547
#
#       VaR 99% Percent   volume_mean  return_mean  return_sigma  return
# 653           33.0320  6.156947e+05     0.025319      0.190321   4.853
# 231           12.4854  8.355594e+06     0.021652      0.075526   4.350
# 1121          36.7117  5.134245e+04     0.019579      0.208017   4.050
# 44            10.1253  9.394618e+04     0.018749      0.063133   3.639
# 1511          19.9841  2.971455e+05     0.018281      0.110493   3.505
# 1541          16.4602  4.452298e+06     0.016131      0.090425   3.359
# 170           13.4391  6.851132e+05     0.016391      0.075468   3.331
# 13            13.3311  2.427746e+05     0.017100      0.074168   3.297
# 547           12.0385  1.754284e+05     0.016824      0.068264   3.230
# 91             8.8263  4.481264e+05     0.013553      0.051464   2.718

# %%
# high price
df[df['start price']>1].sort_values(by='return', ascending=False).head(10)
# Out:
#      code   last_date  start price  sim_mean  sim_diff  VaR 99%  \
# 44    ANO  2019-05-17        4.700      4.87  0.171037   0.4759
# 1569  Z1P  2019-05-17        3.520      3.61  0.089661   0.2423
# 11    5GN  2019-05-17        1.220      1.25  0.028929   0.0989
# 333   BUB  2019-05-17        1.255      1.28  0.027860   0.1241
# 396   CIA  2019-05-17        2.810      2.87  0.056387   0.1960
# 1130  NEA  2019-05-17        3.830      3.91  0.076255   0.2138
# 1099  MGX  2019-05-17        1.255      1.28  0.024473   0.0586
# 893   JIN  2019-05-17       17.640     17.97  0.332156   0.8226
# 475   CRD  2019-05-17        1.725      1.76  0.032102   0.1326
# 568   EXL  2019-05-17        5.310      5.41  0.095579   0.4495
#
#       VaR 99% Percent   volume_mean  return_mean  return_sigma  return
# 44            10.1253  9.394618e+04     0.018749      0.063133   3.639
# 1569           6.8835  2.213021e+06     0.013231      0.041874   2.547
# 11             8.1025  2.783428e+05     0.011851      0.046108   2.371
# 333            9.8893  5.224863e+06     0.012003      0.054048   2.220
# 396            6.9752  2.352005e+05     0.010121      0.040556   2.007
# 1130           5.5820  2.758876e+06     0.009782      0.032158   1.991
# 1099           4.6704  2.889591e+06     0.009759      0.028963   1.950
# 893            4.6631  2.944424e+05     0.009616      0.028292   1.883
# 475            7.6877  2.516973e+05     0.009541      0.043361   1.861
# 568            8.4646  3.914424e+05     0.009079      0.045529   1.800

# %%
# highest price
df[df['return']>0.8].sort_values(by='start price', ascending=False).head(10)
# Out:
#      code   last_date  start price  sim_mean  sim_diff  VaR 99%  \
# 1550  XRO  2019-05-17        61.30     61.87  0.574015   2.4022
# 1000  MFG  2019-05-17        44.82     45.44  0.623908   1.3437
# 92    ALU  2019-05-17        32.61     32.93  0.318376   1.7449
# 423   CUV  2019-05-17        31.46     31.84  0.380826   1.8679
# 55    APT  2019-05-17        25.60     26.03  0.434050   1.7403
# 128   APX  2019-05-17        25.19     25.60  0.406458   1.3748
# 322   BRG  2019-05-17        18.21     18.42  0.210959   0.7374
# 893   JIN  2019-05-17        17.64     17.97  0.332156   0.8226
# 1515  WEB  2019-05-17        16.80     16.96  0.159761   1.2309
# 811   IEL  2019-05-17        16.72     16.91  0.194380   0.7705
#
#       VaR 99% Percent   volume_mean  return_mean  return_sigma  return
# 1550           3.9188  4.080842e+05     0.004924      0.021471   0.936
# 1000           2.9980  5.603837e+05     0.007133      0.018919   1.392
# 92             5.3510  4.877692e+05     0.005079      0.027926   0.976
# 423            5.9375  1.038602e+05     0.006013      0.031563   1.211
# 55             6.7982  2.085872e+06     0.008506      0.038436   1.696
# 128            5.4579  8.024468e+05     0.008101      0.031709   1.614
# 322            4.0492  2.940396e+05     0.006033      0.023060   1.158
# 893            4.6631  2.944424e+05     0.009616      0.028292   1.883
# 1515           7.3267  5.458244e+05     0.004770      0.036727   0.951
# 811            4.6081  6.902328e+05     0.005996      0.025482   1.163

# %%
# low risk
var_threshold = df['VaR 99% Percent'].quantile(0.3)
print(var_threshold)
df[df['VaR 99% Percent'] < var_threshold].sort_values(by='return',
                                                      ascending=False).head(10)
# Out:
# 4.18149
#      code   last_date  start price  sim_mean  sim_diff  VaR 99%  \
# 174   AD8  2019-05-17         7.11      7.21  0.102230   0.2698
# 1000  MFG  2019-05-17        44.82     45.44  0.623908   1.3437
# 519   DDR  2019-05-17         5.14      5.21  0.065844   0.1507
# 322   BRG  2019-05-17        18.21     18.42  0.210959   0.7374
# 731   GOR  2019-05-17         1.01      1.02  0.010536   0.0397
# 1550  XRO  2019-05-17        61.30     61.87  0.574015   2.4022
# 859   IVC  2019-05-17        15.46     15.60  0.136605   0.5705
# 1484  VRL  2019-05-17         3.77      3.80  0.031494   0.0975
# 1454  A2M  2019-05-16        15.38     15.50  0.124667   0.5979
# 1091  MND  2019-05-17        18.97     19.12  0.147956   0.5186
#
#       VaR 99% Percent   volume_mean  return_mean  return_sigma  return
# 174            3.7945  1.804788e+05     0.007450      0.023410   1.438
# 1000           2.9980  5.603837e+05     0.007133      0.018919   1.392
# 519            2.9321  1.273768e+05     0.006611      0.018334   1.281
# 322            4.0492  2.940396e+05     0.006033      0.023060   1.158
# 731            3.9312  2.778099e+06     0.005600      0.022133   1.043
# 1550           3.9188  4.080842e+05     0.004924      0.021471   0.936
# 859            3.6901  4.941825e+05     0.004526      0.020465   0.884
# 1484           2.5873  2.245945e+05     0.004269      0.015027   0.835
# 1454           3.8877  2.953829e+06     0.004275      0.020185   0.811
# 1091           2.7337  3.380912e+05     0.003934      0.015736   0.780

# %%
# high volume
df.sort_values(by='volume_mean', ascending=False).head(10)
# Out:
#      code   last_date  start price  sim_mean  sim_diff  VaR 99%  \
# 1444  TLS  2019-05-16         3.51      3.53  0.015415   0.0910
# 673   FMG  2019-05-17         8.95      9.10  0.147280   0.3999
# 1355  S32  2019-05-17         3.52      3.53  0.010301   0.1112
# 770   HSO  2019-05-17         2.45      2.46  0.009322   0.0427
# 1081  MGR  2019-05-17         2.95      2.97  0.015053   0.0595
# 1480  VCX  2019-05-17         2.58      2.58 -0.001136   0.0657
# 95    AWC  2019-05-17         2.39      2.40  0.007973   0.0885
# 104   AMP  2019-05-17         2.20      2.20 -0.001418   0.1135
# 1293  SCG  2019-05-17         3.84      3.84 -0.001305   0.0999
# 1160  NEC  2019-05-17         1.88      1.89  0.012056   0.0848
#
#       VaR 99% Percent   volume_mean  return_mean  return_sigma  return
# 1444           2.5924  2.634859e+07     0.002249      0.013454   0.439
# 673            4.4678  1.893690e+07     0.008612      0.027161   1.646
# 1355           3.1585  1.817144e+07     0.001425      0.015186   0.293
# 770            1.7432  1.284986e+07     0.001942      0.009660   0.380
# 1081           2.0178  1.271401e+07     0.002683      0.011212   0.510
# 1480           2.5471  1.225923e+07    -0.000244      0.011103  -0.044
# 95             3.7025  1.186764e+07     0.001834      0.017616   0.334
# 104            5.1586  1.176785e+07    -0.000381      0.022085  -0.064
# 1293           2.6020  1.164832e+07    -0.000170      0.011574  -0.034
# 1160           4.5131  9.392770e+06     0.003329      0.023546   0.641

# %%
# plt.figure(figsize=(16,8))
df['volume_mean'].quantile(0.2)
# Out:
# 103866.52121212121

# %%
# 2019-05-17 recommendations
selection = [
    'AVH',  # high return & high risk
    'ANO',  # high return & high risk
    'AGH',  # high return & meduim risk
    'Z1P',  # medium price & risk
    'MFG',  # high price & low risk
    'AD8',  # low risk
    'FMG',  # high volume & low risk
]
df[df['code'].isin(selection)].sort_values(by='return', ascending=False).head(10)
# Out:
#      code   last_date  start price  sim_mean  sim_diff  VaR 99%  \
# 231   AVH  2019-05-16         0.49      0.51  0.021313   0.0612
# 44    ANO  2019-05-17         4.70      4.87  0.171037   0.4759
# 91    AGH  2019-05-17         0.62      0.64  0.016855   0.0547
# 1569  Z1P  2019-05-17         3.52      3.61  0.089661   0.2423
# 673   FMG  2019-05-17         8.95      9.10  0.147280   0.3999
# 174   AD8  2019-05-17         7.11      7.21  0.102230   0.2698
# 1000  MFG  2019-05-17        44.82     45.44  0.623908   1.3437
#
#       VaR 99% Percent   volume_mean  return_mean  return_sigma  return
# 231           12.4854  8.355594e+06     0.021652      0.075526   4.350
# 44            10.1253  9.394618e+04     0.018749      0.063133   3.639
# 91             8.8263  4.481264e+05     0.013553      0.051464   2.718
# 1569           6.8835  2.213021e+06     0.013231      0.041874   2.547
# 673            4.4678  1.893690e+07     0.008612      0.027161   1.646
# 174            3.7945  1.804788e+05     0.007450      0.023410   1.438
# 1000           2.9980  5.603837e+05     0.007133      0.018919   1.392
