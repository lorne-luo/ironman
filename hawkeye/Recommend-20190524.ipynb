# %% [markdown]
# Step 1. [Download history price and clean data](/notebooks/forex/hawkeye/1_download.ipynb)
#
# Step 2. [Use monte carlo simulate each stock's movement for 10000 times](/notebooks/forex/hawkeye/2_process.ipynb)
#
# **Step 3. Apply some heuristic rules to give stock recommendation**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys

sys.path.append('/opt/hawkeye')
from asx import *

this_week=20190524
last_week=20190517
path = f'/opt/hawkeye/data/{this_week}/result.csv'
last_path = f'/opt/hawkeye/data/{last_week}/result.csv'

def week_return_avg(df):
    return round(df['week_return'].dropna().sum()/len(df['week_return'].dropna()),4)

df = pd.read_csv(path,
                 usecols=[
                     'code', 'last_date', 'start price', 'sim_mean',
                     'sim_diff', 'VaR 99%', 'VaR 99% Percent', 'volume_mean',
                     'return_mean', 'return_sigma'
                 ],
                 index_col='code')
last_df = pd.read_csv(last_path,
                      usecols=[
                          'code', 'last_date', 'start price', 'sim_mean',
                          'sim_diff', 'VaR 99%', 'VaR 99% Percent',
                          'volume_mean', 'return_mean', 'return_sigma'
                      ],
                      index_col='code')

print(f'Total stock number = {len(df)}')

# remove bottom volume and bottom price
volume_threshold = df['volume_mean'].quantile(0.1)
df = df[(df['volume_mean'] > volume_threshold) & (df['start price'] > 0.05)]

# calculate return & risk rank
df['return'] = round(df['sim_diff'] / df['start price'] * 100, 3)
df['return_rank'] = round(df['return'].rank(pct=True) * 100, 3)
df['risk_rank'] = round(df['VaR 99% Percent'].rank(pct=True) * 100, 3)
df['volume_rank'] = round(df['volume_mean'].rank(pct=True) * 100, 3)

# last week performance
df['last_return'] = round(last_df['sim_diff'] / last_df['start price'] * 100,3)
df['return_increase'] = df['return'] - df['last_return']
df['week_return'] = round(
    (df['start price'] - last_df['start price']) / df['start price'] * 100, 3)

# drop used columns
df.drop(columns=['sim_diff', 'sim_mean', 'VaR 99%','VaR 99% Percent', 'volume_mean'], inplace=True)

print(f'Total stock number after bottom volume & price removed = {len(df)}')
print('Price 70%% pricetile = %s' % df['start price'].quantile(0.7))
print('Sim return 90%% percentile = %s' % df['return'].quantile(0.9))

df.sort_values(by='return', ascending=False).head(20)
# Out:
# Total stock number = 940
# Total stock number after bottom volume & price removed = 725
# Price 70% pricetile = 2.411999999999998
# Sim return 90% percentile = 1.1268000000000005
#        last_date  start price  return_mean  return_sigma  return  return_rank  \
# code
# ANO   2019-05-27        7.020     0.022919      0.066730   4.705      100.000
# AVH   2019-05-27        0.455     0.020646      0.075820   3.976       99.862
# LTR   2019-05-28        0.110     0.018294      0.092349   3.816       99.724
# 8CO   2019-05-27        0.155     0.017755      0.075269   3.636       99.586
# WZR   2019-05-28        0.170     0.018665      0.100016   3.627       99.448
# FEX   2019-05-28        0.094     0.017862      0.091920   3.483       99.310
# ATU   2019-05-27        0.340     0.016598      0.075959   3.341       99.172
# ISX   2019-05-27        0.660     0.016576      0.056584   3.180       99.034
# LBT   2019-05-28        0.205     0.015325      0.151159   3.003       98.897
# NET   2019-05-28        0.090     0.014647      0.085266   2.818       98.759
# WKT   2019-05-28        0.315     0.013642      0.052351   2.707       98.621
# 5GN   2019-05-27        1.350     0.012917      0.046811   2.579       98.483
# MAU   2019-05-27        0.390     0.012489      0.064433   2.429       98.345
# Z1P   2019-05-28        3.460     0.012759      0.042866   2.412       98.207
# BUB   2019-05-27        1.265     0.011732      0.053853   2.362       98.069
# ZNO   2019-05-28        0.150     0.011910      0.131387   2.350       97.931
# DUB   2019-05-27        0.995     0.010932      0.053923   2.199       97.793
# CV1   2019-05-27        0.125     0.010657      0.052824   2.198       97.655
# BKT   2019-05-27        0.098     0.011024      0.054184   2.123       97.517
# WHK   2019-05-28        0.145     0.009958      0.066897   2.051       97.379
#
#       risk_rank  volume_rank  last_return  return_increase  week_return
# code
# ANO      77.931       10.483        3.639            1.066       33.048
# AVH      88.828       98.345        4.350           -0.374       -7.692
# LTR      96.000       98.759        2.795            1.021       35.455
# 8CO      90.483       35.862        3.297            0.339        0.000
# WZR      98.759       94.897        3.359            0.268       17.647
# FEX      96.966       98.207        2.660            0.823       17.021
# ATU      89.793       63.724        3.331            0.010       -2.941
# ISX      70.345       82.897        1.653            1.527       49.242
# LBT     100.000       70.483        0.011            2.992       60.000
# NET      96.414       88.552        3.224           -0.406      -11.111
# WKT      66.621       64.552        2.563            0.144       11.111
# 5GN      58.759       43.448        2.371            0.208        9.630
# MAU      85.655        4.828        2.043            0.386       17.949
# Z1P      54.759       85.655        2.547           -0.135       -1.734
# BUB      71.448       94.759        2.220            0.142        0.791
# ZNO      99.862       27.310        2.586           -0.236       -6.667
# DUB      72.552       58.759        1.714            0.485       10.553
# CV1      70.483       42.207        1.666            0.532        8.000
# BKT      72.690       77.655        2.612           -0.489       -7.143
# WHK      88.690       84.000        1.377            0.674       24.138

# %%
# high mean return 
df.sort_values(by='return', ascending=False).head(10)
# Out:
#        last_date  start price  return_mean  return_sigma  return  return_rank  \
# code
# ANO   2019-05-27        7.020     0.022919      0.066730   4.705      100.000
# AVH   2019-05-27        0.455     0.020646      0.075820   3.976       99.862
# LTR   2019-05-28        0.110     0.018294      0.092349   3.816       99.724
# 8CO   2019-05-27        0.155     0.017755      0.075269   3.636       99.586
# WZR   2019-05-28        0.170     0.018665      0.100016   3.627       99.448
# FEX   2019-05-28        0.094     0.017862      0.091920   3.483       99.310
# ATU   2019-05-27        0.340     0.016598      0.075959   3.341       99.172
# ISX   2019-05-27        0.660     0.016576      0.056584   3.180       99.034
# LBT   2019-05-28        0.205     0.015325      0.151159   3.003       98.897
# NET   2019-05-28        0.090     0.014647      0.085266   2.818       98.759
#
#       risk_rank  volume_rank  last_return  return_increase  week_return
# code
# ANO      77.931       10.483        3.639            1.066       33.048
# AVH      88.828       98.345        4.350           -0.374       -7.692
# LTR      96.000       98.759        2.795            1.021       35.455
# 8CO      90.483       35.862        3.297            0.339        0.000
# WZR      98.759       94.897        3.359            0.268       17.647
# FEX      96.966       98.207        2.660            0.823       17.021
# ATU      89.793       63.724        3.331            0.010       -2.941
# ISX      70.345       82.897        1.653            1.527       49.242
# LBT     100.000       70.483        0.011            2.992       60.000
# NET      96.414       88.552        3.224           -0.406      -11.111

# %%
# high price
df[df['start price']>1].sort_values(by='return', ascending=False).head(10)
# Out:
#        last_date  start price  return_mean  return_sigma  return  return_rank  \
# code
# ANO   2019-05-27        7.020     0.022919      0.066730   4.705      100.000
# 5GN   2019-05-27        1.350     0.012917      0.046811   2.579       98.483
# Z1P   2019-05-28        3.460     0.012759      0.042866   2.412       98.207
# BUB   2019-05-27        1.265     0.011732      0.053853   2.362       98.069
# CIA   2019-05-27        2.900     0.010158      0.039037   1.979       96.690
# JIN   2019-05-27       17.130     0.009134      0.027798   1.802       96.138
# MGX   2019-05-27        1.245     0.009362      0.028459   1.773       96.000
# NEA   2019-05-27        3.440     0.008758      0.033279   1.752       95.586
# CRD   2019-05-27        1.660     0.008834      0.043928   1.750       95.379
# FMG   2019-05-27        8.450     0.008591      0.027545   1.673       95.034
#
#       risk_rank  volume_rank  last_return  return_increase  week_return
# code
# ANO      77.931       10.483        3.639            1.066       33.048
# 5GN      58.759       43.448        2.371            0.208        9.630
# Z1P      54.759       85.655        2.547           -0.135       -1.734
# BUB      71.448       94.759        2.220            0.142        0.791
# CIA      50.759       36.000        2.007           -0.028        3.103
# JIN      28.828       43.034        1.883           -0.081       -2.977
# MGX      28.966       88.690        1.950           -0.177       -0.803
# NEA      44.000       88.000        1.991           -0.239      -11.337
# CRD      59.724       37.517        1.861           -0.111       -3.916
# FMG      29.793       99.862        1.646            0.027       -5.917

# %%
# highest price
df[df['return']>0.8].sort_values(by='start price', ascending=False).head(10)
# Out:
#        last_date  start price  return_mean  return_sigma  return  return_rank  \
# code
# MFG   2019-05-27        43.90     0.006793      0.019041   1.330       92.276
# CUV   2019-05-27        33.68     0.006901      0.033153   1.339       92.552
# APX   2019-05-27        26.24     0.007777      0.032044   1.559       94.483
# APT   2019-05-27        23.93     0.007714      0.038569   1.505       93.379
# BRG   2019-05-27        17.28     0.005489      0.023411   1.061       88.138
# JIN   2019-05-27        17.13     0.009134      0.027798   1.802       96.138
# IEL   2019-05-27        16.59     0.005701      0.025645   1.111       89.517
# IVC   2019-05-27        15.97     0.004838      0.020115   0.948       85.103
# WEB   2019-05-28        15.15     0.004333      0.037057   0.831       81.724
# LOV   2019-05-27        11.60     0.007034      0.033448   1.305       92.000
#
#       risk_rank  volume_rank  last_return  return_increase  week_return
# code
# MFG      12.276       59.172        1.392           -0.062       -2.096
# CUV      46.897       13.931        1.211            0.128        6.591
# APX      40.966       67.034        1.614           -0.055        4.002
# APT      51.310       83.172        1.696           -0.191       -6.979
# BRG      25.655       41.793        1.158           -0.097       -5.382
# JIN      28.828       43.034        1.883           -0.081       -2.977
# IEL      31.448       64.138        1.163           -0.052       -0.784
# IVC      19.862       56.828        0.884            0.064        3.193
# WEB      55.862       59.310        0.951           -0.120      -10.891
# LOV      46.069       43.310        1.111            0.194        8.621

# %%
# low risk
low_risk = df.sort_values(by='risk_rank', ascending=True).head(20).sort_values(by='return', ascending=False)
print('Low risk last week performance avg. = %s%%'% week_return_avg(low_risk))
low_risk
# Out:
# Low risk last week performance avg. = 0.155%
#        last_date  start price  return_mean  return_sigma  return  return_rank  \
# code
# CHC   2019-05-27       10.570     0.003729      0.010259   0.709       77.379
# MGR   2019-05-27        3.120     0.003588      0.010326   0.690       76.414
# ASX   2019-05-27       76.420     0.002721      0.008721   0.526       68.000
# AMC   2019-05-27       16.160     0.002333      0.007838   0.454       63.103
# DXS   2019-05-27       13.160     0.002309      0.009577   0.453       62.828
# BXB   2019-05-27       12.190     0.002195      0.009808   0.444       62.621
# CMW   2019-05-27        1.190     0.002109      0.007670   0.421       60.483
# SHL   2019-05-28       26.260     0.002152      0.008966   0.394       57.931
# AST   2019-05-27        1.790     0.001817      0.007741   0.365       55.931
# GOZ   2019-05-27        4.340     0.001619      0.008181   0.315       52.276
# HSO   2019-05-27        2.460     0.001342      0.006879   0.253       48.414
# CIP   2019-05-27        3.050     0.001276      0.008614   0.243       47.310
# CMA   2019-05-27        2.610     0.001258      0.006701   0.236       46.414
# AVN   2019-05-27        2.270     0.000819      0.008553   0.157       40.414
# WLE   2019-05-28        1.120     0.000634      0.007827   0.115       37.724
# ARG   2019-05-27        7.990     0.000552      0.006291   0.106       36.690
# WGB   2019-05-28        2.050     0.000487      0.008261   0.095       35.586
# APD   2019-05-27        0.445     0.000432      0.008025   0.077       33.103
# IGL   2019-05-27        2.110     0.000375      0.008370   0.069       32.276
# NEW   2019-05-27        1.360    -0.000263      0.007789  -0.048       24.000
#
#       risk_rank  volume_rank  last_return  return_increase  week_return
# code
# CHC       1.241       80.276        0.665            0.044        0.662
# MGR       1.379       99.448        0.510            0.180        5.449
# ASX       0.966       45.379        0.561           -0.035        0.406
# AMC       0.690       91.724        0.532           -0.078       -2.723
# DXS       2.069       91.172        0.356            0.097        0.912
# BXB       2.345       91.448        0.453           -0.009       -3.035
# CMW       0.138       92.552        0.392            0.029        0.420
# SHL       1.655       73.241        0.424           -0.030       -0.724
# AST       0.828       92.966        0.327            0.038       -3.911
# GOZ       1.103       58.621        0.303            0.012       -0.230
# HSO       0.414       99.586        0.380           -0.127        0.407
# CIP       1.517       23.034        0.199            0.044        0.000
# CMA       0.276       55.862        0.190            0.046        2.299
# AVN       2.483       44.000        0.229           -0.072        0.000
# WLE       1.793       62.621        0.093            0.022        1.339
# ARG       0.552       25.379        0.067            0.039        2.503
# WGB       2.207       29.517        0.148           -0.053        0.488
# APD       1.931       16.414        0.044            0.033        0.000
# IGL       2.759       28.690        0.172           -0.103       -1.896
# NEW       2.621        5.517       -0.015           -0.033        0.735

# %%
# high volume
df.sort_values(by='volume_rank', ascending=False).head(20)
# Out:
#        last_date  start price  return_mean  return_sigma  return  return_rank  \
# code
# TLS   2019-05-28        3.540     0.002428      0.012408   0.476       64.414
# FMG   2019-05-27        8.450     0.008591      0.027545   1.673       95.034
# S32   2019-05-28        3.475     0.000969      0.014498   0.215       44.759
# HSO   2019-05-27        2.460     0.001342      0.006879   0.253       48.414
# MGR   2019-05-27        3.120     0.003588      0.010326   0.690       76.414
# AWC   2019-05-27        2.430     0.001813      0.017312   0.364       55.724
# VCX   2019-05-28        2.700     0.000752      0.010502   0.156       40.276
# SCG   2019-05-27        3.920     0.000541      0.010721   0.084       33.793
# AMP   2019-05-27        2.180    -0.000726      0.021988  -0.148       18.897
# LTR   2019-05-28        0.110     0.018294      0.092349   3.816       99.724
# NEC   2019-05-27        1.990     0.004487      0.023480   0.885       83.586
# BPT   2019-05-27        1.925     0.004434      0.025849   0.836       81.931
# AVH   2019-05-27        0.455     0.020646      0.075820   3.976       99.862
# FEX   2019-05-28        0.094     0.017862      0.091920   3.483       99.310
# MPL   2019-05-27        3.250     0.002998      0.017241   0.597       71.724
# SGP   2019-05-28        4.485     0.002587      0.012647   0.501       66.069
# EVN   2019-05-27        3.690     0.000459      0.021513   0.102       36.276
# 4DS   2019-05-27        0.070     0.004689      0.077607   0.945       84.828
# WHC   2019-05-28        4.210     0.000271      0.021083   0.096       35.793
# BHP   2019-05-27       37.940     0.001485      0.011803   0.252       48.207
#
#       risk_rank  volume_rank  last_return  return_increase  week_return
# code
# TLS       6.207      100.000        0.439            0.037        0.847
# FMG      29.793       99.862        1.646            0.027       -5.917
# S32      13.379       99.724        0.293           -0.078       -1.295
# HSO       0.414       99.586        0.380           -0.127        0.407
# MGR       1.379       99.448        0.510            0.180        5.449
# AWC      19.310       99.310        0.334            0.030        1.646
# VCX       5.655       99.172       -0.044            0.200        4.444
# SCG       6.069       99.034       -0.034            0.118        2.041
# AMP      36.966       98.897       -0.064           -0.084       -0.917
# LTR      96.000       98.759        2.795            1.021       35.455
# NEC      27.586       98.621        0.641            0.244        5.528
# BPT      34.345       98.483        0.993           -0.157       -9.091
# AVH      88.828       98.345        4.350           -0.374       -7.692
# FEX      96.966       98.207        2.660            0.823       17.021
# MPL      16.000       98.069        0.342            0.255       11.385
# SGP       7.034       97.931        0.185            0.316       12.598
# EVN      32.414       97.793        0.204           -0.102       -0.271
# 4DS      94.897       97.655        1.042           -0.097        1.429
# WHC      32.000       97.517        0.095            0.001       -0.713
# BHP       8.276       97.379        0.379           -0.127       -1.160

# %%
# highest market cap.
highest_market_cap = [
    'BHP', 'RIO', 'CBA', 'WBC', 'CSL', 'ANZ', 'NAB', 'MQG', 'WOW', 'WES',
    'TLS', 'WPL'
    'S32', 'FMG', 'BXB', 'NCM', 'IAG', 'SUN', 'AMC', 'QBE', 'CIM', 'ALL',
    'AGL', 'ASX', 'RHC', 'OSH', 'SHL', 'TWE', 'REA', 'COH'
]
asx_20 = get_asx_20_list()
df[df.index.isin(asx_20)].sort_values(by='return', ascending=False).head(20)
# Out:
#        last_date  start price  return_mean  return_sigma  return  return_rank  \
# code
# RIO   2019-05-27      103.020     0.003350      0.013688   0.648       74.207
# TLS   2019-05-28        3.540     0.002428      0.012408   0.476       64.414
# AMC   2019-05-27       16.160     0.002333      0.007838   0.454       63.103
# BXB   2019-05-27       12.190     0.002195      0.009808   0.444       62.621
# WES   2019-05-28       38.150     0.002222      0.012288   0.430       61.517
# ANZ   2019-05-27       27.820     0.001955      0.014615   0.394       57.931
# WPL   2019-05-28       36.005     0.001754      0.011270   0.350       54.759
# WBC   2019-05-28       27.920     0.001572      0.015265   0.319       52.552
# IAG   2019-05-27        7.890     0.001560      0.010892   0.301       51.448
# MQG   2019-05-27      120.800     0.001600      0.011300   0.300       51.310
# BHP   2019-05-27       37.940     0.001485      0.011803   0.252       48.207
# NAB   2019-05-27       25.830     0.001302      0.011747   0.243       47.310
# CBA   2019-05-27       77.640     0.001252      0.011544   0.240       46.897
# CSL   2019-05-27      206.650     0.001224      0.011405   0.233       45.793
# S32   2019-05-28        3.475     0.000969      0.014498   0.215       44.759
# WOW   2019-05-28       32.210     0.001159      0.010449   0.214       44.552
# COL   2019-05-27       12.500     0.000757      0.013974   0.170       41.103
# SUN   2019-05-28       13.410     0.000842      0.011762   0.169       40.828
# SCG   2019-05-27        3.920     0.000541      0.010721   0.084       33.793
#
#       risk_rank  volume_rank  last_return  return_increase  week_return
# code
# RIO       8.000       80.690        0.647            0.001        1.621
# TLS       6.207      100.000        0.439            0.037        0.847
# AMC       0.690       91.724        0.532           -0.078       -2.723
# BXB       2.345       91.448        0.453           -0.009       -3.035
# WES       7.724       86.345        0.335            0.095        4.692
# ANZ      13.931       95.034        0.242            0.152        7.081
# WPL       5.931       85.379        0.520           -0.170       -3.319
# WBC      14.207       96.966        0.195            0.124        8.990
# IAG       5.379       94.345        0.342           -0.041       -1.774
# MQG       5.517       68.552        0.282            0.018        0.720
# BHP       8.276       97.379        0.379           -0.127       -1.160
# NAB       7.310       96.690        0.163            0.080        7.395
# CBA       6.483       88.966        0.185            0.055        6.195
# CSL       6.345       67.724        0.352           -0.119        0.068
# S32      13.379       99.724        0.293           -0.078       -1.295
# WOW       4.966       89.379        0.386           -0.172       -6.116
# COL      12.828       90.207        0.161            0.009       -3.440
# SUN       9.517       90.897        0.108            0.061       -0.932
# SCG       6.069       99.034       -0.034            0.118        2.041

# %% [markdown]
# ## Thisk week recommendations

# %%
# 2019-05-17 recommendations
selection = [
    'AVH',  # high return & high risk
    'ANO',  # high return & high risk
    'AGH',  # high return & meduim risk
    'Z1P',  # medium price & risk
    'MFG',  # high price & low risk
    'AD8',  # low risk
    'FMG',  # high volume & low risk
]
last_week_df = df[df.index.isin(selection)]
last_week_df.sort_values(by='return', ascending=False).head(10)
# Out:
#        last_date  start price  return_mean  return_sigma  return  return_rank  \
# code
# ANO   2019-05-27        7.020     0.022919      0.066730   4.705      100.000
# AVH   2019-05-27        0.455     0.020646      0.075820   3.976       99.862
# Z1P   2019-05-28        3.460     0.012759      0.042866   2.412       98.207
# AGH   2019-05-27        0.660     0.010286      0.045925   2.032       97.103
# FMG   2019-05-27        8.450     0.008591      0.027545   1.673       95.034
# AD8   2019-05-27        7.120     0.007307      0.024062   1.440       92.966
# MFG   2019-05-27       43.900     0.006793      0.019041   1.330       92.276
#
#       risk_rank  volume_rank  last_return  return_increase  week_return
# code
# ANO      77.931       10.483        3.639            1.066       33.048
# AVH      88.828       98.345        4.350           -0.374       -7.692
# Z1P      54.759       85.655        2.547           -0.135       -1.734
# AGH      60.828       53.379        2.718           -0.686        6.061
# FMG      29.793       99.862        1.646            0.027       -5.917
# AD8      23.862       27.862        1.438            0.002        0.140
# MFG      12.276       59.172        1.392           -0.062       -2.096

# %%
week_return = round(sum(last_week_df['week_return'])/len(selection), 3)
win_rate = round(len(last_week_df[last_week_df['week_return'] >= 0]) / len(selection), 3)
print('Last week average return:', week_return, ' , win rate:', win_rate)
# Out:
# Last week average return: 3.116  , win rate: 0.429

# %% [markdown]
# ## Last week review

# %%
selection = [
    'AVH',  # high return & high risk
    'ANO',  # high return & high risk
    'AGH',  # high return & meduim risk
    'Z1P',  # medium price & risk
    'MFG',  # high price & low risk
    'AD8',  # low risk
    'FMG',  # high volume & low risk
]
df[df.index.isin(selection)].sort_values(by='return', ascending=False).head(10)
# Out:
#        last_date  start price  return_mean  return_sigma  return  return_rank  \
# code
# ANO   2019-05-27        7.020     0.022919      0.066730   4.705      100.000
# AVH   2019-05-27        0.455     0.020646      0.075820   3.976       99.862
# Z1P   2019-05-28        3.460     0.012759      0.042866   2.412       98.207
# AGH   2019-05-27        0.660     0.010286      0.045925   2.032       97.103
# FMG   2019-05-27        8.450     0.008591      0.027545   1.673       95.034
# AD8   2019-05-27        7.120     0.007307      0.024062   1.440       92.966
# MFG   2019-05-27       43.900     0.006793      0.019041   1.330       92.276
#
#       risk_rank  volume_rank  last_return  return_increase  week_return
# code
# ANO      77.931       10.483        3.639            1.066       33.048
# AVH      88.828       98.345        4.350           -0.374       -7.692
# Z1P      54.759       85.655        2.547           -0.135       -1.734
# AGH      60.828       53.379        2.718           -0.686        6.061
# FMG      29.793       99.862        1.646            0.027       -5.917
# AD8      23.862       27.862        1.438            0.002        0.140
# MFG      12.276       59.172        1.392           -0.062       -2.096

# %% [markdown]
# ## Signle performance review

# %%
df[df.index=='FEX']
# Out:
# Empty DataFrame
# Columns: [last_date, start price, VaR 99% Percent, volume_mean, return_mean, return_sigma, return, last_return, return_increase, week_return]
# Index: []

# %% [markdown]
# # Return & Risk Rank

# %%
df['rank'] = df['return_rank'] + (100 - df['risk_rank'])
top_df = df.sort_values(by='rank', ascending=False).head(20)
week_return = round(sum(top_df['week_return'].dropna())/len(top_df), 3)
print('Top rank last week average return:', week_return)
top_df
# Out:
# Top rank last week average return: 1.551
#        last_date  start price  return_mean  return_sigma  return  return_rank  \
# code
# MFG   2019-05-27       43.900     0.006793      0.019041   1.330       92.276
# CHC   2019-05-27       10.570     0.003729      0.010259   0.709       77.379
# MGR   2019-05-27        3.120     0.003588      0.010326   0.690       76.414
# DDR   2019-05-27        5.120     0.006555      0.021161   1.264       91.310
# AD8   2019-05-27        7.120     0.007307      0.024062   1.440       92.966
# MND   2019-05-27       19.430     0.003830      0.015268   0.736       78.759
# JIN   2019-05-27       17.130     0.009134      0.027798   1.802       96.138
# MGX   2019-05-27        1.245     0.009362      0.028459   1.773       96.000
# ASX   2019-05-27       76.420     0.002721      0.008721   0.526       68.000
# RIO   2019-05-27      103.020     0.003350      0.013688   0.648       74.207
# IVC   2019-05-27       15.970     0.004838      0.020115   0.948       85.103
# FMG   2019-05-27        8.450     0.008591      0.027545   1.673       95.034
# ASB   2019-05-27        2.860     0.004389      0.018662   0.841       82.069
# CSR   2019-05-27        4.090     0.004111      0.018461   0.816       81.310
# GOR   2019-05-27        1.090     0.005240      0.021955   1.001       86.483
# GMG   2019-05-27       13.780     0.002642      0.011453   0.511       67.172
# JBH   2019-05-27       27.920     0.003106      0.014808   0.614       72.759
# SSM   2019-05-28        2.495     0.004215      0.018239   0.766       79.448
# BRG   2019-05-27       17.280     0.005489      0.023411   1.061       88.138
# AMC   2019-05-27       16.160     0.002333      0.007838   0.454       63.103
#
#       risk_rank  volume_rank  last_return  return_increase  week_return  \
# code
# MFG      12.276       59.172        1.392           -0.062       -2.096
# CHC       1.241       80.276        0.665            0.044        0.662
# MGR       1.379       99.448        0.510            0.180        5.449
# DDR      18.069       20.690        1.281           -0.017       -0.391
# AD8      23.862       27.862        1.438            0.002        0.140
# MND      11.034       46.621        0.780           -0.044        2.367
# JIN      28.828       43.034        1.883           -0.081       -2.977
# MGX      28.966       88.690        1.950           -0.177       -0.803
# ASX       0.966       45.379        0.561           -0.035        0.406
# RIO       8.000       80.690        0.647            0.001        1.621
# IVC      19.862       56.828        0.884            0.064        3.193
# FMG      29.793       99.862        1.646            0.027       -5.917
# ASB      16.966       70.897        0.726            0.115        4.196
# CSR      17.103       91.310        0.446            0.370       15.648
# GOR      22.621       86.897        1.043           -0.042        7.339
# GMG       4.276       93.241        0.468            0.043        0.508
# JBH       9.931       66.483        0.335            0.279        8.381
# SSM      16.828       76.138        0.734            0.032        1.403
# BRG      25.655       41.793        1.158           -0.097       -5.382
# AMC       0.690       91.724        0.532           -0.078       -2.723
#
#          rank
# code
# MFG   180.000
# CHC   176.138
# MGR   175.035
# DDR   173.241
# AD8   169.104
# MND   167.725
# JIN   167.310
# MGX   167.034
# ASX   167.034
# RIO   166.207
# IVC   165.241
# FMG   165.241
# ASB   165.103
# CSR   164.207
# GOR   163.862
# GMG   162.896
# JBH   162.828
# SSM   162.620
# BRG   162.483
# AMC   162.413
